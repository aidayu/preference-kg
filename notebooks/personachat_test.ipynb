# %%
import pandas as pd
import json
import os
import openai
import time
import logging
from dotenv import load_dotenv
from loguru import logger
import tqdm
import random
from typing import List, Dict, Any

# 環境変数をロード
load_dotenv()
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
dataset_path = "../data/Persona-Chat/personachat/train_self_original.txt"

output_path = "results/personachat.json"

# %%
def parse_personachat(file_path, limit=None):
    """
    PersonaChatのデータをパースする関数
    limit: 読み込むエピソード(セット)の上限数。Noneの場合は全件読み込む。
    """
    dialogues = []
    current_persona = []
    current_history = []
    
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line: continue
            
            space_idx = line.find(' ')
            if space_idx == -1: continue
            
            idx = int(line[:space_idx])
            content = line[space_idx+1:]
            
            # IDが1なら新しいエピソードの開始
            if idx == 1:
                # 前のエピソードがバッファにあれば保存
                if current_persona: 
                    dialogues.append({
                        'persona': current_persona[:],
                        'history': current_history[:]
                    })
                    
                    # ★追加部分: 指定した件数(limit)に達したらここで終了
                    if limit is not None and len(dialogues) >= limit:
                        return dialogues

                # バッファをリセット
                current_persona = []
                current_history = []

            # ペルソナ行の処理
            if content.startswith('your persona:'):
                persona_text = content.replace('your persona:', '').strip()
                current_persona.append(persona_text)
            
            # 会話行の処理
            else:
                if '\t' in content:
                    partner_msg, my_reply = content.split('\t')[:2]
                    current_history.append({'partner': partner_msg, 'me': my_reply})

        # (limitに達せずに)ファイル末尾まで来た場合、最後のバッファを保存
        if current_persona:
            dialogues.append({'persona': current_persona, 'history': current_history})
            
    return dialogues

# %%
# 10セットだけ読み込む
data = parse_personachat(dataset_path, limit=10)

print(f"取得したデータセット数: {len(data)}")
print("-" * 30)

# 全データを表示して確認
for i, episode in enumerate(data):
    print(f"【Set {i+1}】")
    print("[Persona]")
    for p in episode['persona']:
        print(f"  - {p}")
    print("[Dialogue]")
    for turn in episode['history']:
        print(f"  User: {turn['partner']}")
        print(f"  You : {turn['me']}")
    print("-" * 30)
# Out:
# 取得したデータセット数: 10
# ------------------------------
# 【Set 1】
# [Persona]
#   - i like to remodel homes.
#   - i like to go hunting.
#   - i like to shoot a bow.
#   - my favorite holiday is halloween.
# [Dialogue]
#   User: hi , how are you doing ? i am getting ready to do some cheetah chasing to stay in shape .
#   You : you must be very fast . hunting is one of my favorite hobbies .
#   User: i am ! for my hobby i like to do canning or some whittling .
#   You : i also remodel homes when i am not out bow hunting .
#   User: that is neat . when i was in high school i placed 6th in 100m dash !
#   You : that is awesome . do you have a favorite season or time of year ?
#   User: i do not . but i do have a favorite meat since that is all i eat exclusively .
#   You : what is your favorite meat to eat ?
#   User: i would have to say its prime rib . do you have any favorite foods ?
#   You : i like chicken or macaroni and cheese .
#   User: do you have anything planned for today ? i think i am going to do some canning .
#   You : i am going to watch football . what are you canning ?
#   User: i think i will can some jam . do you also play footfall for fun ?
#   You : if i have time outside of hunting and remodeling homes . which is not much !
# ------------------------------
# 【Set 2】
# [Persona]
#   - my mom is my best friend.
#   - i have four sisters.
#   - i believe that mermaids are real.
#   - i love iced tea.
# [Dialogue]
#   User: hi , how are you doing today ?
#   You : i am spending time with my 4 sisters what are you up to
#   User: wow , four sisters . just watching game of thrones .
#   You : that is a good show i watch that while drinking iced tea
#   User: i agree . what do you do for a living ?
#   You : i am a researcher i am researching the fact that mermaids are real
#   User: interesting . i am a website designer . pretty much spend all my time on the computer .
#   You : that is cool my mom does the same thing
#   User: that is awesome . i have always had a love for technology .
#   You : tell me more about yourself
#   User: i really enjoy free diving , how about you , have any hobbies ?
#   You : i enjoy hanging with my mother she is my best friend
#   User: that is nice . moms are pretty cool too .
#   You : i am also fascinated with mermaids
# ------------------------------
# 【Set 3】
# [Persona]
#   - i had a gig at local theater last night.
#   - i work as a stand up comedian.
#   - i come from a small town.
#   - my favorite drink is cuba libre.
#   - i did a few small roles in tv series.
# [Dialogue]
#   User: we all live in a yellow submarine , a yellow submarine . morning !
#   You : hi ! that is a great line for my next stand up .
#   User: lol . i am shy , anything to break the ice , and i am a beatles fan .
#   You : i can tell . i am not , you can see me in some tv shows
#   User: really ? what shows ? i like tv , it makes me forget i do not like my family
#   You : wow , i wish i had a big family . i grew up in a very small town .
#   User: i did too . i do not get along with mine . they have no class .
#   You : just drink some cola with rum and you will forget about them !
#   User: put the lime in the coconut as well . . .
#   You : nah , plain cuba libre , that is what we drank yesterday at the theater .
#   User: i prefer mojitos . watermelon or cucumber .
#   You : those are really yummy too , but not my favorite .
# ------------------------------
# 【Set 4】
# [Persona]
#   - i am very athletic.
#   - i wear contacts.
#   - i have brown hair.
#   - i love bicycling.
#   - i hate carrots.
# [Dialogue]
#   User: hi ! i work as a gourmet cook .
#   You : i do not like carrots . i throw them away .
#   User: really . but , i can sing pitch perfect .
#   You : i also cook , and i ride my bike to work .
#   User: great ! i had won an award for spelling bee .
#   You : my contacts can see through what you are trying to sell me .
#   User: okay but i was published in new yorker once
#   You : you better not make any spelling mistakes .
#   User: i have not . i can cook any word you want me to
#   You : what is your ethnicity ? i am white , and my hair is brown .
#   User: i am asian and have no hair .
#   You : i love hairless asians . do you like carrots ?
#   User: i love carrots . i eat carrots like a horse .
#   You : are you male or female ?
#   User: i work as a gourmet cook who also has a pitch perfect voice .
#   You : i doubt that very much . you probably like to scream alone .
# ------------------------------
# 【Set 5】
# [Persona]
#   - i am primarily a meat eater.
#   - i am a guitar player.
#   - welding is my career field.
#   - my parents do not know i am gay.
# [Dialogue]
#   User: how are you doing today
#   You : what do you do for career ? i have a ton of hobbies if you are interested !
#   User: i like to watch kids
#   You : i actually play guitar and do a lot of manly things , like welding .
#   User: what do you weld ? houses ?
#   You : everything ! i am actually manly . but i have a secret i am hiding .
#   User: what is your secret that you have
#   You : my parents do not know that i am . . . homosexual .
#   User: how does that feel for you
#   You : makes me secure with my manly hobby skills .
#   User: i bet that it does
#   You : anyway . what do you do ?
#   User: i watch kids for a living
#   You : that is awesome . do you like it ?
# ------------------------------
# 【Set 6】
# [Persona]
#   - i own a hearse.
#   - i love to crochet.
#   - i like alternative rock.
#   - halloween is my favorite holiday.
# [Dialogue]
#   User: hello friend , how is it going
#   You : i am well an you ? i have a creepy ride . guess
#   User: i am great enjoying the football season
#   You : i drive around in a long black hearse an love this season
#   User: you work for a funeral home ?
#   You : yes it is nice , halloween is my fav .
#   User: lol , i can imagine . i will be reading a lot when football is over
#   You : no i do not work at a funeral home
#   User: ok i see , that is your halloween costume
#   You : what do you like to read ? i like rock alternative music .
#   User: i like anything to do with mystery
#   You : oh no it is not it is my car lol
#   User: lol , oh i see , taught you own it
#   You : me also what is your favorite ?
#   User: well i like sherlock holmes and others
#   You : i do own it i think there is confusion ?
# ------------------------------
# 【Set 7】
# [Persona]
#   - i have a boxer dog.
#   - i like baths.
#   - i like to listen to music.
#   - my father lives in china.
# [Dialogue]
#   User: rock on , i am listening to my favorite band guns and roses .
#   You : no kidding ? i was just listening to the same thing while taking a bath .
#   User: of course . i love to listen to rock .
#   You : man my boxer just peed on the carpet !
#   User: well i am into black everything . so at least it would not show on my black carpet .
#   You : ll . i love black too ! guess i was playing my music too loud .
#   User: i have a black car , purse , wear all black .
#   You : maybe i can borrow something as i am packing to visit my dad in china .
#   User: wow , does he live there or work ?
#   You : live . moved there about ten years ago for a computer tech job .
#   User: have you visited him there before ?
#   You : once . you cannot even throw a gum wrapper or you can get arrested .
#   User: sounds a bit scary . i ve never been .
#   You : well not too much crime there , but a lot of people .
# ------------------------------
# 【Set 8】
# [Persona]
#   - i like to party.
#   - my major is business.
#   - i am in college.
#   - i love the beach.
#   - i work part time at a pizza restaurant.
# [Dialogue]
#   User: hi . how are you doing today ?
#   You : hi i am great just finishing up some homework how are you
#   User: i am alright . i just got done writing .
#   You : do you write for a living or as a hobby
#   User: it is my living . i like culture .
#   You : that sounds like a fun job . i am a business major but have a part time job
#   User: what are you going to school for
#   You : i am trying to get my ba in finance
#   User: do you own your own company
#   You : no still in school work at pizza hut part time
#   User: do you get free pizza
#   You : no but i do get a good deal .
#   User: that is a good start
#   You : yeah it is . i really hope they have a frat party again soon
#   User: i used to party a lot
#   You : it is fun i cant get enough
# ------------------------------
# 【Set 9】
# [Persona]
#   - i m from texas.
#   - i like basketball.
#   - i work many hours.
#   - my favorite band is imagine dragons.
# [Dialogue]
#   User: hi how are you today
#   You : doing great . i had the day off , you ?
#   User: i only worked half a day i work at the bank
#   You : that is nice . i work a lot
#   User: what do you do ?
#   You : just office work , but it is a lot
#   User: oh ok i am a teller was the best job i could find with no college
#   You : a bank teller is a good job .
#   User: yes it does pay the bills
#   You : when i am not working i play basket ball what do you do for fun
#   User: i hike at the park
#   You : that sounds relaxing , i suppose
#   User: i love nature and it keeps my mind off things . do you travel
#   You : not much . i should though while i am young
#   User: i want to go to another country at least once . i have never left the states
#   You : me either . we could go together !
# ------------------------------
# 【Set 10】
# [Persona]
#   - i like to travel.
#   - i have traveled to both ireland and australia.
#   - my father was born in australia.
#   - my father was an author.
# [Dialogue]
#   User: hello , how are you today ?
#   You : i am well , how are you ?
#   User: i am very good . did you watch the football games today ?
#   You : no but my sons are watching a game right now
#   User: what do you do for a living ? i proofread for hallmark .
#   You : cool . . . i followed my father and became an author
#   User: books are my greatest pleasure , i have a nice little library i am building .
#   You : awesome . . . nothing like filling your mind with literature
#   User: i agree . have you seen goodfellas ?
#   You : not much of a tv guy since i am always traveling
#   User: i catch the football and hockey games .
#   You : have you ever traveled before ?
#   User: i do . i travel extensively to europe and south america .
#   You : ireland and australia are my go to places
#   User: ireland is very nice , japan is my next stop .
#   You : never been there . i heard they are very friendly people
# ------------------------------
